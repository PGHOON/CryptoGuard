# %%
import glob
import pandas as pd

csv_files = glob.glob('*.csv')

syscall_counts = {}

for file_path in csv_files:
    df = pd.read_csv(file_path)
    for syscall in df['SYSTEM_CALL']:
        if syscall in syscall_counts:
            syscall_counts[syscall] += 1
        else:
            syscall_counts[syscall] = 1

sorted_syscall_counts = dict(sorted(syscall_counts.items(), key=lambda item: item[1], reverse=True))
list(sorted_syscall_counts.items())[:299]
# Out:
# [('sys_enter_rt_sigaction', 245263906),
#  ('sys_enter_futex', 65826189),
#  ('sys_enter_pselect6', 34400042),
#  ('sys_enter_epoll_ctl', 30708705),
#  ('sys_enter_rt_sigprocmask', 28117687),
#  ('sys_enter_close', 22860555),
#  ('sys_enter_mmap', 19454798),
#  ('sys_enter_sigaltstack', 18104712),
#  ('sys_enter_socket', 17259858),
#  ('sys_enter_gettid', 16292961),
#  ('sys_enter_setsockopt', 16139975),
#  ('sys_enter_connect', 13899219),
#  ('sys_enter_clone', 9053396),
#  ('sys_enter_read', 5595164),
#  ('sys_enter_sched_yield', 4641782),
#  ('sys_enter_openat', 3748374),
#  ('sys_enter_getpid', 3623530),
#  ('sys_enter_getppid', 3622755),
#  ('sys_enter_bind', 2240312),
#  ('sys_enter_munmap', 1924884),
#  ('sys_enter_pipe2', 1812171),
#  ('sys_enter_execve', 1812059),
#  ('sys_enter_sched_getaffinity', 1811549),
#  ('sys_enter_chdir', 1811519),
#  ('sys_enter_exit_group', 1811372),
#  ('sys_enter_setsid', 1811349),
#  ('sys_enter_fcntl', 1384178),
#  ('sys_enter_readlinkat', 1372822),
#  ('sys_enter_epoll_create1', 691517),
#  ('sys_enter_mprotect', 453144),
#  ('sys_enter_newfstat', 69516),
#  ('sys_enter_getsockopt', 42480),
#  ('sys_enter_epoll_pwait', 42304),
#  ('sys_enter_getdents64', 40105),
#  ('sys_enter_unlinkat', 36468),
#  ('sys_enter_write', 22941),
#  ('sys_enter_clock_gettime', 2075),
#  ('sys_enter_getsockname', 1712),
#  ('sys_enter_newfstatat', 1195),
#  ('sys_enter_brk', 849),
#  ('sys_enter_rt_sigreturn', 833),
#  ('sys_enter_recvfrom', 770),
#  ('sys_enter_waitid', 683),
#  ('sys_enter_wait4', 683),
#  ('sys_enter_rseq', 578),
#  ('sys_enter_set_robust_list', 578),
#  ('sys_enter_clone3', 543),
#  ('sys_enter_getpeername', 409),
#  ('sys_enter_accept4', 408),
#  ('sys_enter_sendto', 367),
#  ('sys_enter_ioctl', 356),
#  ('sys_enter_writev', 350),
#  ('sys_enter_recvmsg', 249),
#  ('sys_enter_sched_setaffinity', 248),
#  ('sys_enter_exit', 158),
#  ('sys_enter_pread64', 140),
#  ('sys_enter_mkdirat', 130),
#  ('sys_enter_fchmodat', 130),
#  ('sys_enter_prlimit64', 127),
#  ('sys_enter_clock_nanosleep', 120),
#  ('sys_enter_madvise', 111),
#  ('sys_enter_faccessat2', 106),
#  ('sys_enter_faccessat', 90),
#  ('sys_enter_lseek', 82),
#  ('sys_enter_eventfd2', 71),
#  ('sys_enter_getrandom', 68),
#  ('sys_enter_listen', 60),
#  ('sys_enter_set_tid_address', 45),
#  ('sys_enter_newuname', 45),
#  ('sys_enter_nanosleep', 44),
#  ('sys_enter_setrlimit', 40),
#  ('sys_enter_umask', 26),
#  ('sys_enter_inotify_init1', 23),
#  ('sys_enter_inotify_add_watch', 23),
#  ('sys_enter_sendmmsg', 17),
#  ('sys_enter_sysinfo', 12),
#  ('sys_enter_prctl', 12),
#  ('sys_enter_getuid', 11),
#  ('sys_enter_clock_getres', 10),
#  ('sys_enter_geteuid', 10),
#  ('sys_enter_getgid', 10),
#  ('sys_enter_getegid', 10),
#  ('sys_enter_kill', 1)]
